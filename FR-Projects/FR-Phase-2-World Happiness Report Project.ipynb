# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')

# %%
df =pd.read_csv('/Users/vinitkoli/Documents/Data Science Journey/Flip Robo Internship Task /Flip Robo Project Assignment /happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
print( "The dimension of the Dataset",df.shape)
print("\n The column headers in the Datasets:", df.columns)
# Out:
# The dimension of the Dataset (158, 12)
#
#  The column headers in the Datasets: Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
# Checking number of unique values in each columns

df.nunique().to_frame("No .of unique Values ")
# Out:
#                                No .of unique Values
# Country                                          158
# Region                                            10
# Happiness Rank                                   157
# Happiness Score                                  157
# Standard Error                                   153
# Economy (GDP per Capita)                         158
# Family                                           158
# Health (Life Expectancy)                         157
# Freedom                                          158
# Trust (Government Corruption)                    157
# Generosity                                       158
# Dystopia Residual                                158

# %%
# Checking the value count 

for i in df.columns:
    print(df[i].value_counts())
    print("\n")
# Out:
# Country
# Switzerland    1
# Bangladesh     1
# Greece         1
# Lebanon        1
# Hungary        1
#               ..
# Kazakhstan     1
# Slovenia       1
# Lithuania      1
# Nicaragua      1
# Togo           1
# Name: count, Length: 158, dtype: int64
#
#
# Region
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: count, dtype: int64
#
#
# Happiness Rank
# 82     2
# 1      1
# 110    1
# 103    1
# 104    1
#       ..
# 54     1
# 55     1
# 56     1
# 57     1
# 158    1
# Name: count, Length: 157, dtype: int64
#
#
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# ...

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
plt.figure(figsize=(22,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap="Blues_r")
plt.xlabel('Figure',fontsize=20)
plt.ylabel('Feature_Name',fontsize=20)
plt.title('Descriptive Graph',fontsize=20)
plt.show()

# %%
ax = sns.countplot(x='Happiness Score',data=df)
print(df['Happiness Score'].value_counts())
# Out:
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: count, Length: 157, dtype: int64

# %%
# Seperating numercial and Categorical columns 

# Checking for Categorical Columns 
categorical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]== "object":
        categorical_col.append(i)
print("Categorical Columns :", categorical_col)
print("\n")  
   
# Checking for Numerical Columns
numerical_col = []
for i in df.dtypes.index:
    if df.dtypes[i]!= "object":
        numerical_col.append(i)
print("Numerical Columns :", numerical_col)
print("\n")
# Out:
# Categorical Columns : ['Country', 'Region']
#
#
# Numerical Columns : ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %%
# Checking hte unique values in the columns 
df.nunique().to_frame("No. of Unique values")
# Out:
#                                No. of Unique values
# Country                                         158
# Region                                           10
# Happiness Rank                                  157
# Happiness Score                                 157
# Standard Error                                  153
# Economy (GDP per Capita)                        158
# Family                                          158
# Health (Life Expectancy)                        157
# Freedom                                         158
# Trust (Government Corruption)                   157
# Generosity                                      158
# Dystopia Residual                               158

# %%
# Checking the distribution of the data 

plt.figure(figsize = (10,6), facecolor="white" )
plotnumber = 1 
for col in numerical_col:
    if plotnumber <=4:
        ax = plt.subplot(2,2,plotnumber)
        sns.distplot(df[col],color ="m")
        plt.xlabel(col, fontsize = 12 )
        plt.yticks(rotation = 0 , fontsize = 10)
    plotnumber += 1
plt.tight_layout()

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# # Bivariate Analysis

# %%
sns.pairplot(df,hue="Happiness Score", palette = "Dark2")
plt.show()

# %% [markdown]
# # Checkiing for Outliers

# %%
# Lets check for the outliers by plotting boxplot 

plt.figure(figsize = (10,6), facecolor="white" )
plotnumber = 1 
for col in numerical_col:
    if plotnumber <=4:
        ax = plt.subplot(2,2,plotnumber)
        sns.boxplot(df[col],palette ="Set2_r")
        plt.xlabel(col, fontsize = 15 )
        plt.yticks(rotation = 0 , fontsize = 10)
    plotnumber += 1
plt.tight_layout()

# %% [markdown]
# # Checking Skewness

# %%
# encoding categorical Columns using Orfinal Encoder 
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder()

for i in df.columns:
    if df[i].dtypes == "object":
        df[i] = OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.distplot(df['Happiness Score'],color="m", kde_kws = {"shade" : True}, hist=False)
plt.show()

# %% [markdown]
# # Encoding  Categorial Column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    float64
#  1   Region                         158 non-null    float64
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.047885                  0.846137    0.991046
# std          0.017146                  0.403121    0.272369
# min          0.018480                  0.000000    0.000000
# 25%          0.037268                  0.545808    0.856823
# ...

# %% [markdown]
# # Corelation between target variable and independent variable

# %%
# Checking the correlation between features and the target 
cor =df.corr()
cor
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
# Visualizing the correlation matrix by plotting heatmap
plt.figure(figsize =(20,15))
sns.heatmap(df.corr(), linewidths = 0.1, fmt = ".1g", linecolor = "black", annot = True, cmap ="Blues_r")
plt.yticks(rotation = 0);
plt.show()

# %%
# Corrleation with all the columns with Target variable 
cor['Happiness Score'].sort_values(ascending = False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Country                          0.083380
# Region                          -0.176791
# Standard Error                  -0.177254
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
# Seperating Features and Labels 

x = df.drop("Happiness Score", axis = 1)
y = df["Happiness Score"]

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#       Country    Region  Happiness Rank  Standard Error  \
# 0    1.238770  1.300256       -1.721000       -0.805926
# 1   -0.449465  1.300256       -1.699075        0.055889
# 2   -0.909893  1.300256       -1.677149       -0.854487
# 3    0.581016  1.300256       -1.655224       -0.531526
# 4   -1.194920 -0.040302       -1.633299       -0.722845
# ..        ...       ...             ...             ...
# 153  0.866043  0.965117        1.633576       -0.774917
# 154 -1.436096  0.965117        1.655501       -0.662582
# 155  1.260695 -0.375441        1.677427        0.132534
# 156 -1.260695  0.965117        1.699352        2.263962
# 157  1.370321  0.965117        1.721277        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# ...

# %% [markdown]
# # Checking Variance Inflation Factor ( VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['VIF values '] = [variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
vif["Features"] = x.columns
vif
# Out:
#     VIF values                        Features
# 0      1.082092                        Country
# 1      1.455402                         Region
# 2     76.549524                 Happiness Rank
# 3      1.188841                 Standard Error
# 4     13.586284       Economy (GDP per Capita)
# 5      5.636951                         Family
# 6      8.136093       Health (Life Expectancy)
# 7      3.258351                        Freedom
# 8      2.044527  Trust (Government Corruption)
# 9      2.124602                     Generosity
# 10    18.139857              Dystopia Residual

# %%
y.value_counts()
# Out:
# Happiness Score
# 5.192    2
# 7.587    1
# 4.686    1
# 4.839    1
# 4.800    1
#         ..
# 5.855    1
# 5.848    1
# 5.833    1
# 5.828    1
# 2.839    1
# Name: count, Length: 157, dtype: int64

# %%
# importing necessary libraries 
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression 
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso,Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import ExtraTreesRegressor

# %%
# Finding the best Random state 

maxAccu =0
macRs=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.30, random_state=i)
    RFR=RandomForestRegressor()
    RFR.fit(x_train,y_train)
    pred = RFR.predict(x_test)
    acc =r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
print("Maximum r2 score is : ",maxAccu, "on Random State :",maxRs)
# Out:
# Maximum r2 score is :  0.8068325973504616 on Random State : 148

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.30, random_state = maxRs)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print(LR)
print('R2_score :',r2_score(y_test,pred_LR))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error :',mean_squared_error(y_test,pred_LR))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# LinearRegression()
# R2_score : 0.5567374527180053
# R2_Score training Data : 50.1731749064139
# Mean Absolute Error : 0.2790873580781179
# Mean Squared Error : 0.11041670052794487
# Root Mean Squared Error : 0.3322900849076675

# %%
RFR  = RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print(RFR)
print('R2_score :',r2_score(y_test,pred_RFR))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error :',mean_squared_error(y_test,pred_RFR))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# RandomForestRegressor()
# R2_score : 0.8085775458316606
# R2_Score training Data : 95.39839589663171
# Mean Absolute Error : 0.1248
# Mean Squared Error : 0.047683333333333335
# Root Mean Squared Error : 0.21836513763266638

# %%
knn = KNN()
knn.fit(x_train,y_train)
pred_knn = knn.predict(x_test)
pred_train = knn.predict(x_train)
print(knn)
print('R2_score :',r2_score(y_test,pred_knn))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error :',mean_squared_error(y_test,pred_knn))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# KNeighborsRegressor()
# R2_score : 0.6049779205138497
# R2_Score training Data : 64.09552745924401
# Mean Absolute Error : 0.20133333333333334
# Mean Squared Error : 0.09840000000000003
# Root Mean Squared Error : 0.3136877428271625

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print(GBR)
print('R2_score :',r2_score(y_test,pred_GBR))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error :',mean_squared_error(y_test,pred_GBR))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# GradientBoostingRegressor()
# R2_score : 0.7944429848981807
# R2_Score training Data : 88.11828696531549
# Mean Absolute Error : 0.1455010451687221
# Mean Squared Error : 0.0512042524618632
# Root Mean Squared Error : 0.2262835664865286

# %%
lasso = Lasso()
lasso.fit(x_train,y_train)
pred_lasso = lasso.predict(x_test)
pred_train = lasso.predict(x_train)
print(lasso)
print('R2_score :',r2_score(y_test,pred_lasso))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_lasso))
print('Mean Squared Error :',mean_squared_error(y_test,pred_lasso))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_lasso)))
# Out:
# Lasso()
# R2_score : -0.00689011052032229
# R2_Score training Data : 0.0
# Mean Absolute Error : 0.5006857142857143
# Mean Squared Error : 0.25081632653061225
# Root Mean Squared Error : 0.5008156612273744

# %%
rd = Ridge()
rd.fit(x_train,y_train)
pred_rd = rd.predict(x_test)
pred_train = rd.predict(x_train)
print(rd)
print('R2_score :',r2_score(y_test,pred_rd))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error :',mean_squared_error(y_test,pred_rd))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# Ridge()
# R2_score : 0.5584630005169418
# R2_Score training Data : 50.19321419109072
# Mean Absolute Error : 0.2772577456234615
# Mean Squared Error : 0.10998686657122982
# Root Mean Squared Error : 0.33164267905568157

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr = dtr.predict(x_test)
pred_train = dtr.predict(x_train)
print(dtr)
print('R2_score :',r2_score(y_test,pred_dtr))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error :',mean_squared_error(y_test,pred_dtr))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# DecisionTreeRegressor()
# R2_score : 0.4915027432088852
# R2_Score training Data : 100.0
# Mean Absolute Error : 0.12666666666666668
# Mean Squared Error : 0.12666666666666668
# Root Mean Squared Error : 0.3559026084010437

# %%
svr = SVR()
svr.fit(x_train,y_train)
pred_svr = svr.predict(x_test)
pred_train = svr.predict(x_train)
print(rd)
print('R2_score :',r2_score(y_test,pred_svr))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_svr))
print('Mean Squared Error :',mean_squared_error(y_test,pred_svr))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# Ridge()
# R2_score : 0.6740325787303048
# R2_Score training Data : 67.21379505978061
# Mean Absolute Error : 0.19646129081671812
# Mean Squared Error : 0.08119848463828105
# Root Mean Squared Error : 0.28495347802453835

# %%
etr = ExtraTreesRegressor()
etr.fit(x_train,y_train)
pred_etr = etr.predict(x_test)
pred_train = etr.predict(x_train)
print(etr)
print('R2_score :',r2_score(y_test,pred_etr))
print('R2_Score training Data :',r2_score(y_train,pred_train)*100)
print('Mean Absolute Error :',mean_absolute_error(y_test,pred_etr))
print('Mean Squared Error :',mean_squared_error(y_test,pred_etr))
print('Root Mean Squared Error :',np.sqrt(mean_squared_error(y_test,pred_etr)))
# Out:
# ExtraTreesRegressor()
# R2_score : 0.8078174762478254
# R2_Score training Data : 100.0
# Mean Absolute Error : 0.12419999999999999
# Mean Squared Error : 0.04787266666666667
# Root Mean Squared Error : 0.21879823277775043

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,x,y, cv=5, scoring = 'r2')
print(score)
print(score.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_LR) - score.mean())*100)
# Out:
# [0.54080064 0.51152506 0.53408414 0.47196401 0.51292339]
# 0.5142594469648544
# Difference between R2 and cross validation score is :  4.247800575315097

# %%
score1 = cross_val_score(RFR,x,y, cv=5, scoring = 'r2')
print(score1)
print(score1.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_RFR) - score1.mean())*100)
# Out:
# [0.72926293 0.70939403 0.749988   0.64314787 0.76928486]
# 0.7202155364973448
# Difference between R2 and cross validation score is :  8.83620093343158

# %%
score2 = cross_val_score(knn,x,y, cv=5, scoring = 'r2')
print(score2)
print(score2.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_knn) - score2.mean())*100)
# Out:
# [0.53435344 0.56265702 0.5728     0.39849624 0.58092949]
# 0.5298472365039121
# Difference between R2 and cross validation score is :  7.513068400993761

# %%
score3 = cross_val_score(GBR,x,y, cv=5, scoring = 'r2')
print(score3)
print(score3.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_GBR) - score3.mean())*100)
# Out:
# [0.70677031 0.7217271  0.71485904 0.66600869 0.7312306 ]
# 0.7081191456819692
# Difference between R2 and cross validation score is :  8.632383921621145

# %%
score4 = cross_val_score(lasso,x,y, cv=5, scoring = 'r2')
print(score4)
print(score4.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_lasso) - score4.mean())*100)
# Out:
# [-2.25022502e-04 -8.13988544e-03 -6.25000000e-06 -3.60902256e-03
#  -2.25986579e-03]
# -0.0028480092565093427
# Difference between R2 and cross validation score is :  -0.4042101263812947

# %%
score5 = cross_val_score(rd,x,y, cv=5, scoring = 'r2')
print(score5)
print(score5.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_rd) - score5.mean())*100)
# Out:
# [0.54086754 0.51268464 0.5341011  0.47193797 0.51295401]
# 0.514509050087228
# Difference between R2 and cross validation score is :  4.395395042971373

# %%
score6 = cross_val_score(dtr,x,y, cv=5, scoring = 'r2')
print(score6)
print(score6.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_dtr) - score6.mean())*100)
# Out:
# [0.41994199 0.47743945 0.36       0.39849624 0.61939103]
# 0.45505374275264465
# Difference between R2 and cross validation score is :  3.6449000456240555

# %%
score7 = cross_val_score(svr,x,y, cv=5, scoring = 'r2')
print(score7)
print(score7.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_svr) - score7.mean())*100)
# Out:
# [0.53089575 0.52282604 0.5906512  0.44082442 0.6550866 ]
# 0.5480568023312633
# Difference between R2 and cross validation score is :  12.597577639904145

# %%
score8 = cross_val_score(etr,x,y, cv=5, scoring = 'r2')
print(score8)
print(score8.mean())
print("Difference between R2 and cross validation score is : ",(r2_score(y_test,pred_etr) - score8.mean())*100)
# Out:
# [0.72044604 0.74079188 0.761382   0.70036692 0.78237981]
# 0.741073329960609
# Difference between R2 and cross validation score is :  6.674414628721637

# %%
from sklearn.model_selection import GridSearchCV

param = {
    'n_estimators': [5, 10, 20],  # Number of trees in the forest
    'max_features': ['auto', 'sqrt', 'log2'],  # Number of features to consider at every split
    'max_depth': [None, 10, 20, 30],  # Maximum depth of the trees
    'min_samples_split': [2, 5, 10],  # Minimum number of samples required to split an internal node
    'min_samples_leaf': [1, 2, 4],  # Minimum number of samples required to be at a leaf node
    'bootstrap': [True, False],  # Method of selecting samples for training each tree
    'random_state': range(1, 20)
}

# %%
gscv = GridSearchCV(RandomForestRegressor(), param, cv=5)
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'max_depth': [None, 10, 20, 30],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [5, 10, 20],
#                          'random_state': range(1, 20)})

# %%
# Creating same Grid search and changing the parameters 
final_model = RandomForestRegressor(max_features='sqrt', max_depth=10, n_estimators=10,
                                    min_samples_leaf=2, min_samples_split=5, random_state=15)

final_model.fit(x_train, y_train)
pred = final_model.predict(x_test)
r2 = r2_score(y_test, pred)
mse = mean_squared_error(y_test, pred)
print('R2_score :',r2_score(y_test,pred))
print('Mean Absolute Error :', mean_absolute_error(y_test,pred))
print('Mean Squared Error :', mean_squared_error(y_test,pred))
print('Root Mean Squared Error : ', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_score : 0.7587100337190285
# Mean Absolute Error : 0.1473189507806467
# Mean Squared Error : 0.060105330600589986
# Root Mean Squared Error :  0.24516388518823481

# %%
import joblib

# %%
import pickle
filename = 'WorldHappinesReport.pk1'
pickle.dump(final_model,open(filename, 'wb'))    # save model and wb- write binary

# %%
import pickle 
loaded_model = pickle.load(open('WorldHappinesReport.pk1','rb'))       #  rb- read binary 
result = loaded_model.score(x_test,y_test)
print(result*100)
# Out:
# 75.87100337190284

# %%
conclusion = pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=["Predicted","Original"])
conclusion
# Out:
#                 0    1    2        3         4         5         6    7    \
# Predicted  0.408929  1.0  0.8  0.59881  0.808333  0.236605  0.335494  0.0
# Original   0.000000  1.0  0.0  1.00000  1.000000  0.000000  0.000000  0.0
#
#                 8    9    ...       290       291  292   293  294  295  296  \
# Predicted  0.011111  0.0  ...  0.054938  0.616667  0.0  0.05  1.0  0.9  1.0
# Original   0.000000  0.0  ...  0.000000  1.000000  0.0  0.00  1.0  1.0  1.0
#
#                 297  298       299
# Predicted  0.396429  1.0  0.245833
# Original   1.000000  1.0  0.000000
#
# [2 rows x 300 columns]
